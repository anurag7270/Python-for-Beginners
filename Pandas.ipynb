# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
# Prior to Pandas, Python was majorly used for data munging and preparation. It had very little contribution towards data analysis. Pandas solved this problem. Using Pandas, we can accomplish five typical steps in the processing and analysis of data, regardless of the origin of data — load, prepare, manipulate, model, and analyze.
#
# Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc.

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
# Let's make a table -->rows, columns
df = pd.DataFrame(np.arange(0,20).reshape(5,4),index = ['Row1','Row2','Row3','Row4','Row5'],
                  columns =['Column1','Column2','Column3','Column4',])

# %%
df.head()
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
# loc-->row
# iloc--r,c
#access the elements
df.loc['Row1']
# Out:
# Column1    0
# Column2    1
# Column3    2
# Column4    3
# Name: Row1, dtype: int32

# %%
# type
type(df.loc['Row1'])

# Data frames
# data series
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,:]
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
#indexing
df.iloc[:,1:3]
# Out:
#       Column2  Column3
# Row1        1        2
# Row2        5        6
# Row3        9       10
# Row4       13       14
# Row5       17       18

# %%
# creating array
df.iloc[:,1:3].values
# Out:
# array([[ 1,  2],
#        [ 5,  6],
#        [ 9, 10],
#        [13, 14],
#        [17, 18]])

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
#to count the values
df['Column1'].value_counts()
# Out:
# 0     1
# 8     1
# 4     1
# 16    1
# 12    1
# Name: Column1, dtype: int64

# %%
df= pd.read_csv('original_trial.csv')

# %%
df.head()
# Out:
#        rp     snr   (snr)^0.5      ber    2*snr    2*ber   snr+ber  \
# 0 -53.301  87.699    9.364774  0.00013  175.398  0.00026  87.69913
# 1 -53.307  87.693    9.364454  0.00013  175.386  0.00026  87.69313
# 2 -53.310  87.690    9.364294  0.00013  175.380  0.00026  87.69013
# 3 -53.316  87.684    9.363974  0.00013  175.368  0.00026  87.68413
# 4 -53.319  87.681    9.363813  0.00013  175.362  0.00026  87.68113
#
#    (snr+ber)^2  s parameter        mean  label
# 0  7691.137406       -9.301  887.632967      1
# 1  7690.085056       -9.307  887.512003      1
# 2  7689.558908       -9.310  887.451525      1
# 3  7688.506664       -9.316  887.330573      1
# 4  7687.980570       -9.319  887.270100      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rp           736 non-null    float64
#  1   snr          736 non-null    float64
#  2    (snr)^0.5   736 non-null    float64
#  3   ber          736 non-null    float64
#  4   2*snr        736 non-null    float64
#  5   2*ber        736 non-null    float64
#  6   snr+ber      736 non-null    float64
#  7   (snr+ber)^2  736 non-null    float64
#  8   s parameter  736 non-null    float64
#  9   mean         736 non-null    float64
#  10  label        736 non-null    int64
# dtypes: float64(10), int64(1)
# memory usage: 63.4 KB

# %%
df.describe()
# Out:
#                rp         snr   (snr)^0.5         ber       2*snr       2*ber  \
# count  736.000000  736.000000  736.000000  736.000000  736.000000  736.000000
# mean   -51.302576   89.697424    9.462209    0.000127  179.394848    0.000254
# std      7.769397    7.769397    0.405268    0.000021   15.538794    0.000042
# min    -64.202000   76.798000    8.763447    0.000082  153.596000    0.000164
# 25%    -56.401000   84.599000    9.197752    0.000113  169.198000    0.000227
# 50%    -51.501000   89.499000    9.460058    0.000125  178.998000    0.000250
# 75%    -47.105250   93.894750    9.689930    0.000140  187.789500    0.000279
# max    -30.651000  110.349000   10.504713    0.000170  220.698000    0.000339
#
#           snr+ber   (snr+ber)^2  s parameter         mean      label
# count  736.000000    736.000000   736.000000   736.000000  736.00000
# mean    89.697551   8105.931828    -7.302576   935.064343    0.50000
# std      7.769376   1440.716672     7.769397   165.293778    0.50034
# min     76.798170   5897.958846   -20.202000   681.056775    0.00000
# 25%     84.599140   7157.134443   -12.401000   826.214084    0.00000
# 50%     89.499125   8012.346355    -7.501000   924.533435    0.50000
# 75%     93.894863   8816.245380    -3.105250  1016.811584    1.00000
# max    110.349082  12176.919920    13.349000  1401.279885    1.00000

# %%
df['ber'].value_counts()
# Out:
# 0.000082    15
# 0.000082    14
# 0.000082    12
# 0.000082     5
# 0.000114     2
#             ..
# 0.000116     1
# 0.000131     1
# 0.000111     1
# 0.000129     1
# 0.000142     1
# Name: ber, Length: 648, dtype: int64

# %%
df[df['ber']>10]
# Out:
# Empty DataFrame
# Columns: [rp, snr,  (snr)^0.5, ber, 2*snr, 2*ber, snr+ber, (snr+ber)^2, s parameter, mean, label]
# Index: []

# %%
#CORRELATION---> mutual relationship or connection between two or more things.
df.corr()
# Out:
#                    rp       snr   (snr)^0.5       ber     2*snr     2*ber  \
# rp           1.000000  1.000000    0.999498 -0.983280  1.000000 -0.983279
# snr          1.000000  1.000000    0.999498 -0.983280  1.000000 -0.983279
#  (snr)^0.5   0.999498  0.999498    1.000000 -0.988540  0.999498 -0.988539
# ber         -0.983280 -0.983280   -0.988540  1.000000 -0.983280  1.000000
# 2*snr        1.000000  1.000000    0.999498 -0.983280  1.000000 -0.983279
# 2*ber       -0.983279 -0.983279   -0.988539  1.000000 -0.983279  1.000000
# snr+ber      1.000000  1.000000    0.999498 -0.983280  1.000000 -0.983279
# (snr+ber)^2  0.997952  0.997952    0.995426 -0.969699  0.997952 -0.969697
# s parameter  1.000000  1.000000    0.999498 -0.983280  1.000000 -0.983279
# mean         0.998080  0.998080    0.995618 -0.970191  0.998080 -0.970189
# label        0.006655  0.006655    0.006754 -0.007151  0.006655 -0.007147
#
#               snr+ber  (snr+ber)^2  s parameter      mean     label
# rp           1.000000     0.997952     1.000000  0.998080  0.006655
# snr          1.000000     0.997952     1.000000  0.998080  0.006655
#  (snr)^0.5   0.999498     0.995426     0.999498  0.995618  0.006754
# ber         -0.983280    -0.969699    -0.983280 -0.970191 -0.007151
# 2*snr        1.000000     0.997952     1.000000  0.998080  0.006655
# 2*ber       -0.983279    -0.969697    -0.983279 -0.970189 -0.007147
# snr+ber      1.000000     0.997952     1.000000  0.998080  0.006655
# (snr+ber)^2  0.997952     1.000000     0.997952  0.999998  0.006438
# s parameter  1.000000     0.997952     1.000000  0.998080  0.006655
# mean         0.998080     0.999998     0.998080  1.000000  0.006446
# label        0.006655     0.006438     0.006655  0.006446  1.000000

# %%
import numpy as np

# %%
lst_data = [[1,2,3],[3,4,np.nan],[5,6,np.nan],[np.nan,np.nan,np.nan]]

# %%
df=pd.DataFrame(lst_data)

# %%
df.head()
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  3.0  4.0  NaN
# 2  5.0  6.0  NaN
# 3  NaN  NaN  NaN

# %%
df.iloc[0:3,0:2]
# Out:
#      0    1
# 0  1.0  2.0
# 1  3.0  4.0
# 2  5.0  6.0

# %%
#droping nan values
df.dropna(axis=0)
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
